# %%
# %pip install -q matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.8.0

# %%
img=cv2.imread('../img/OpenCV_Logo_with_text.png')

# %%
cv2.imshow(img, cmap=plt.cm.gray_r, interpolation='nearest')
plt.title('obraz')

plt.show()

# %%
plt.xticks([])  

plt.yticks([])  
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('obraz')
plt.show()

# %%
# Out:
# ([], [])
